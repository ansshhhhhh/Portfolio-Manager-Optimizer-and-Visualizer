# %%
from Portfolio.portfolio import Portfolio
from Visualizer.Visualizer import PortfolioVisualization

# %%
companies = [
    "AAPL", "GOOG"
]

my_portfolio = Portfolio(companies)
my_portfolio.clean_data()
my_portfolio.calculate_return()
# Out:
# [*********************100%***********************]  2 of 2 completed
#
# 2 Failed downloads:
# ['AAPL', 'GOOG']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  2 of 2 completed
#
# 2 Failed downloads:
# ['AAPL', 'GOOG']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# Data cleaned successfully.
# Return Calculated.

# %%
viz1 = PortfolioVisualization(my_portfolio)
viz1.plot_asset_performance()
viz1.plot_correlation_heatmap()
viz1.plot_rolling_volatility()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 viz1 = PortfolioVisualization(my_portfolio)
# ----> 2 viz1.plot_asset_performance()
#       3 viz1.plot_correlation_heatmap()
#       4 viz1.plot_rolling_volatility()
#
# File ~/Projects/Portfolio-Manager-Optimizer-and-Visualizer/Visualizer/Visualizer.py:57, in PortfolioVisualization.plot_asset_performance(self)
#      56 def plot_asset_performance(self):
# ---> 57     norm = self.asset_prices / self.asset_prices.iloc[0]
#      58     plt.figure(figsize=(10, 5))
#      59     norm.plot()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1625, in _iLocIndexer._getitem_axis(self, key, axis)
#    1622     raise TypeError("Cannot index by location index with a non-integer key")
#    1624 # validate the location
# -> 1625 self._validate_integer(key, axis)
#    1627 return self.obj._ixs(key, axis=axis)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1557, in _iLocIndexer._validate_integer(self, key, axis)
#    1555 len_axis = len(self.obj._get_axis(axis))
#    1556 if key >= len_axis or key < -len_axis:
# -> 1557     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %%
my_portfolio.weights
# Out:
# array([0.5, 0.5])

# %%
old_performance = my_portfolio.performance()
print(old_performance)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_15548/2662641323.py in ?()
# ----> 1 old_performance = my_portfolio.performance()
#       2 print(old_performance)
#
# ~/Projects/Portfolio-Manager-Optimizer-and-Visualizer/Portfolio/portfolio.py in ?(self)
#     103             ['Sharpe Ratio', sharpe_ratio(self.portfolio_daily_return)],
#     104             ['Max Drawdown', max_drawdown(self.portfolio_daily_return)]
#     105         ]
#     106
# --> 107         return tabulate(table,  headers='firstrow', tablefmt='github')
#
# ~/anaconda3/lib/python3.11/site-packages/tabulate/__init__.py in ?(tabular_data, headers, tablefmt, floatfmt, intfmt, numalign, stralign, missingval, showindex, disable_numparse, colalign, maxcolwidths, rowalign, maxheadercolwidths)
#    2044
#    2045     if tabular_data is None:
#    2046         tabular_data = []
#    2047
# -> 2048     list_of_lists, headers = _normalize_tabular_data(
#    2049         tabular_data, headers, showindex=showindex
#    2050     )
#    2051     list_of_lists, separating_lines = _remove_separating_lines(list_of_lists)
#
# ~/anaconda3/lib/python3.11/site-packages/tabulate/__init__.py in ?(tabular_data, headers, showindex)
#    1467         headers = []
#    1468
#    1469     headers = list(map(str, headers))
#    1470     #    rows = list(map(list, rows))
# -> 1471     rows = list(map(lambda r: r if _is_separating_line(r) else list(r), rows))
#    1472
#    1473     # add or remove an index column
#    1474     showindex_is_a_str = type(showindex) in [str, bytes]
#
# ~/anaconda3/lib/python3.11/site-packages/tabulate/__init__.py in ?(r)
# -> 1471     rows = list(map(lambda r: r if _is_separating_line(r) else list(r), rows))
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self)
#    1525     @final
#    1526     def __nonzero__(self) -> NoReturn:
# -> 1527         raise ValueError(
#    1528             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
viz1.visualize_portfolio_performance()

# %%
my_portfolio.optimize()
# Out:
# Weights updated succesfully

# %%
my_portfolio.weights
# Out:
# array([0.5, 0.5])

# %%
my_portfolio.calculate_return()
new_performance = my_portfolio.performance()
print(new_performance)
# Out:
# Return Calculated.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_15548/1869006304.py in ?()
#       1 my_portfolio.calculate_return()
# ----> 2 new_performance = my_portfolio.performance()
#       3 print(new_performance)
#
# ~/Projects/Portfolio-Manager-Optimizer-and-Visualizer/Portfolio/portfolio.py in ?(self)
#     103             ['Sharpe Ratio', sharpe_ratio(self.portfolio_daily_return)],
#     104             ['Max Drawdown', max_drawdown(self.portfolio_daily_return)]
#     105         ]
#     106
# --> 107         return tabulate(table,  headers='firstrow', tablefmt='github')
#
# ~/anaconda3/lib/python3.11/site-packages/tabulate/__init__.py in ?(tabular_data, headers, tablefmt, floatfmt, intfmt, numalign, stralign, missingval, showindex, disable_numparse, colalign, maxcolwidths, rowalign, maxheadercolwidths)
#    2044
#    2045     if tabular_data is None:
#    2046         tabular_data = []
#    2047
# -> 2048     list_of_lists, headers = _normalize_tabular_data(
#    2049         tabular_data, headers, showindex=showindex
#    2050     )
#    2051     list_of_lists, separating_lines = _remove_separating_lines(list_of_lists)
#
# ~/anaconda3/lib/python3.11/site-packages/tabulate/__init__.py in ?(tabular_data, headers, showindex)
#    1467         headers = []
#    1468
#    1469     headers = list(map(str, headers))
#    1470     #    rows = list(map(list, rows))
# -> 1471     rows = list(map(lambda r: r if _is_separating_line(r) else list(r), rows))
#    1472
#    1473     # add or remove an index column
#    1474     showindex_is_a_str = type(showindex) in [str, bytes]
#
# ~/anaconda3/lib/python3.11/site-packages/tabulate/__init__.py in ?(r)
# -> 1471     rows = list(map(lambda r: r if _is_separating_line(r) else list(r), rows))
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self)
#    1525     @final
#    1526     def __nonzero__(self) -> NoReturn:
# -> 1527         raise ValueError(
#    1528             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
viz2 = PortfolioVisualization(my_portfolio)
viz2.visualize_portfolio_performance()

# %%
print('Old performance\n')
print(old_performance)

print('\n\nNew performance\n')
print(new_performance)
# Out:
# Old performance
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 print('Old performance\n')
# ----> 2 print(old_performance)
#       4 print('\n\nNew performance\n')
#       5 print(new_performance)
#
# NameError: name 'old_performance' is not defined
